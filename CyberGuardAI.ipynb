# %%
import pandas as pd
import numpy as np

np.random.seed(42)

# Normal traffic
normal_traffic = {
    "packet_size": np.random.randint(50, 150, size=1000),  # Small packet sizes
    "num_packets": np.random.randint(1, 10, size=1000),    # Few packets
    "protocol_type": np.random.choice([0, 1], size=1000),  # 0 = TCP, 1 = UDP
    "label": 0
}

# Anomalous traffic
anomalous_traffic = {
    "packet_size": np.random.randint(500, 1000, size=50),  # Large packet sizes
    "num_packets": np.random.randint(20, 50, size=50),     # Many packets
    "protocol_type": np.random.choice([0, 1], size=50),    # 0 = TCP, 1 = UDP
    "label": 1  # 1 = anomaly
}


df_normal = pd.DataFrame(normal_traffic)
df_anomalous = pd.DataFrame(anomalous_traffic)
df = pd.concat([df_normal, df_anomalous], ignore_index=True) # Combine into one dataset

df = df.sample(frac=1, random_state=42).reset_index(drop=True)


print(df.head())
# Out:
#    packet_size  num_packets  protocol_type  label
# 0           79            5              0      0
# 1           88            4              0      0
# 2          107            9              0      0
# 3           67            5              0      0
# 4          108            8              1      0

# %%
# Out:
# IsolationForest(contamination=0.05)

# %%
# Predict anomalies
df["anomaly"] = model.predict(X)  # -1 = anomaly, 1 = normal

# Check the results
print(df[["label", "anomaly"]].head())
# Out:
#    label  anomaly
# 0      0        1
# 1      0        1
# 2      0        1
# 3      0        1
# 4      0        1

# %%
from sklearn.metrics import classification_report

# Convert predictions to binary: 1 for anomaly, 0 for normal
df["anomaly_binary"] = df["anomaly"].apply(lambda x: 1 if x == -1 else 0)

# Print a classification report
print(classification_report(df["label"], df["anomaly_binary"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1000
#            1       0.94      1.00      0.97        50
#
#     accuracy                           1.00      1050
#    macro avg       0.97      1.00      0.98      1050
# weighted avg       1.00      1.00      1.00      1050

# %%
import time

# Simulate real-time data streaming
for i in range(0, len(df), 10):  # Process 10 rows at a time
    batch = df.iloc[i:i+10]  # Get a batch of data
    predictions = model.predict(batch.drop(columns=["label", "anomaly", "anomaly_binary"]))

    # Print anomalies
    anomalies = batch[predictions == -1]
    if not anomalies.empty:
        print(f"Anomalies detected in batch {i//10 + 1}:")
        print(anomalies[["packet_size", "num_packets", "protocol_type"]])

    time.sleep(1)  # Wait 1 second to simulate real-time
# Out:
# Anomalies detected in batch 2:
#     packet_size  num_packets  protocol_type
# 15          560           39              1
# Anomalies detected in batch 5:
#     packet_size  num_packets  protocol_type
# 45           50            1              0
# 48          565           27              1
# Anomalies detected in batch 6:
#     packet_size  num_packets  protocol_type
# 50          971           38              0
# Anomalies detected in batch 8:
#     packet_size  num_packets  protocol_type
# 78          826           40              1
# Anomalies detected in batch 11:
#      packet_size  num_packets  protocol_type
# 106          844           31              0
# Anomalies detected in batch 12:
#      packet_size  num_packets  protocol_type
# 119          941           27              0
# Anomalies detected in batch 14:
#      packet_size  num_packets  protocol_type
# 132          611           49              0
# Anomalies detected in batch 15:
#      packet_size  num_packets  protocol_type
# 144          527           43              1
# Anomalies detected in batch 18:
#      packet_size  num_packets  protocol_type
# 172          882           36              1
# 177          597           45              1
# Anomalies detected in batch 19:
#      packet_size  num_packets  protocol_type
# 183          883           34              0
# Anomalies detected in batch 20:
#      packet_size  num_packets  protocol_type
# 193          585           39              1
# Anomalies detected in batch 21:
#      packet_size  num_packets  protocol_type
# 201          717           35              1
# Anomalies detected in batch 22:
#      packet_size  num_packets  protocol_type
# 211          924           47              0
# Anomalies detected in batch 24:
#      packet_size  num_packets  protocol_type
# 232          660           46              0
# Anomalies detected in batch 35:
#      packet_size  num_packets  protocol_type
# 348          870           41              1
# Anomalies detected in batch 37:
#      packet_size  num_packets  protocol_type
# 365          829           45              1
# 367          902           26              0
# Anomalies detected in batch 41:
#      packet_size  num_packets  protocol_type
# 405          804           48              1
# Anomalies detected in batch 42:
#      packet_size  num_packets  protocol_type
# 414          895           27              1
# Anomalies detected in batch 43:
#      packet_size  num_packets  protocol_type
# 427          586           21              0
# Anomalies detected in batch 45:
#      packet_size  num_packets  protocol_type
# 447           50            1              0
# Anomalies detected in batch 47:
#      packet_size  num_packets  protocol_type
# 461          556           22              0
# Anomalies detected in batch 49:
#      packet_size  num_packets  protocol_type
# 480          829           31              0
# 482          788           45              1
# Anomalies detected in batch 52:
#      packet_size  num_packets  protocol_type
# 519          989           26              1
# Anomalies detected in batch 55:
#      packet_size  num_packets  protocol_type
# 547          668           34              0
# Anomalies detected in batch 60:
#      packet_size  num_packets  protocol_type
# 596          585           39              1
# 598          148            9              0
# Anomalies detected in batch 66:
#      packet_size  num_packets  protocol_type
# 654          676           47              1
# Anomalies detected in batch 69:
#      packet_size  num_packets  protocol_type
# 689          580           23              1
# Anomalies detected in batch 70:
#      packet_size  num_packets  protocol_type
# 694          516           33              1
# 697          597           46              1
# Anomalies detected in batch 71:
#      packet_size  num_packets  protocol_type
# 706          953           48              1
# Anomalies detected in batch 73:
#      packet_size  num_packets  protocol_type
# 726          944           25              0
# Anomalies detected in batch 74:
#      packet_size  num_packets  protocol_type
# 732          695           38              1
# Anomalies detected in batch 77:
#      packet_size  num_packets  protocol_type
# 764          920           35              1
# Anomalies detected in batch 78:
#      packet_size  num_packets  protocol_type
# 777          542           40              0
# Anomalies detected in batch 82:
#      packet_size  num_packets  protocol_type
# 812          697           27              1
# Anomalies detected in batch 83:
#      packet_size  num_packets  protocol_type
# 829          677           29              0
# Anomalies detected in batch 85:
#      packet_size  num_packets  protocol_type
# 846          853           34              0
# Anomalies detected in batch 86:
#      packet_size  num_packets  protocol_type
# 852          521           43              0
# Anomalies detected in batch 88:
#      packet_size  num_packets  protocol_type
# 878          616           22              0
# Anomalies detected in batch 94:
#      packet_size  num_packets  protocol_type
# 938          564           47              1
# Anomalies detected in batch 95:
#      packet_size  num_packets  protocol_type
# 941          922           41              0
# Anomalies detected in batch 98:
#      packet_size  num_packets  protocol_type
# 970          651           33              0
# Anomalies detected in batch 99:
#      packet_size  num_packets  protocol_type
# 984          840           43              0
# 985          504           21              1
# Anomalies detected in batch 100:
#      packet_size  num_packets  protocol_type
# 996          993           28              1
# Anomalies detected in batch 102:
#       packet_size  num_packets  protocol_type
# 1016          840           36              0
# Anomalies detected in batch 103:
#       packet_size  num_packets  protocol_type
# 1023          560           41              0
# Anomalies detected in batch 105:
#       packet_size  num_packets  protocol_type
# 1048          501           44              0
